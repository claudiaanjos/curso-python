# %% [markdown]
# Prof. Fernando Amaral
#
# www.eia.ai

# %% [markdown]
# # Testes

# %%
from primo import primo
print(primo(7))
print(primo(8))
# Out:
# True
# True

# %%
# !pytest -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.13, pytest-3.6.4, py-1.11.0, pluggy-0.7.1 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 4 items
#
# test_1.py::test_primo[2-True] FAILED                                     [ 25%]
# test_1.py::test_primo[6-False] PASSED                                    [ 50%]
# test_1.py::test_primo[13-True] PASSED                                    [ 75%]
# test_1.py::test_primo[-1-False] FAILED                                   [100%]
#
# =================================== FAILURES ===================================
# ______________________________ test_primo[2-True] ______________________________
#
# num = 2, res = True
#
#     @pytest.mark.parametrize("num,res",[(2,True),(6,False),(13,True),(-1,False)])
#     def test_primo(num,res):
# >     assert primo(num) == res
# E     assert None == True
# ...

# %%
from primo import primo
print(primo(2))
print(primo(-1))
print(primo(7))
print(primo(8))
# Out:
# True
# False
# True
# False

# %%
# !pytest -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.13, pytest-3.6.4, py-1.11.0, pluggy-0.7.1 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 4 items
#
# test_1.py::test_primo[2-True] PASSED                                     [ 25%]
# test_1.py::test_primo[6-False] PASSED                                    [ 50%]
# test_1.py::test_primo[13-True] PASSED                                    [ 75%]
# test_1.py::test_primo[-1-False] PASSED                                   [100%]
#
# =========================== 4 passed in 0.02 seconds ===========================
