# %% [markdown]
# Prof. Fernando Amaral
#
# www.eia.ai

# %% [markdown]
# # Testes

# %%
import pytest

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.13, pytest-3.6.4, py-1.11.0, pluggy-0.7.1
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 1 item
#
# test_1.py .                                                              [100%]
#
# =========================== 1 passed in 0.02 seconds ===========================

# %%
# !pytest -v

# %%
# !pytest test_2.py -v

# %%
# !pytest -k im -v

# %%
# !pytest -m primarios -v

# %%
# !pytest -m primarios -v

# %%
# !pytest -k test_par3 -v

# %%
# !pytest -k test_par3 -v --maxfail 1
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.13, pytest-3.6.4, py-1.11.0, pluggy-0.7.1 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 7 items / 3 deselected
#
# test_1.py::test_par3[10-2] PASSED                                        [ 25%]
# test_1.py::test_par3[3-20] FAILED                                        [ 50%]
#
# =================================== FAILURES ===================================
# _______________________________ test_par3[3-20] ________________________________
#
# num1 = 3, num2 = 2
#
#     @pytest.mark.parametrize("num1,num2",[(10,2),(3,2),(3,2),(12,4)])
#     def test_par3(num1,num2):
# >     assert num1 % num2 == 0
# E     assert (3 % 2) == 0
#
# test_1.py:13: AssertionError
# =============== 1 failed, 1 passed, 3 deselected in 0.03 seconds ===============

# %%
# !pytest -k test_par3 -v --junitxml="resultadoteste.xml"
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.13, pytest-3.6.4, py-1.11.0, pluggy-0.7.1 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 7 items / 3 deselected
#
# test_1.py::test_par3[10-2] PASSED                                        [ 25%]
# test_1.py::test_par3[3-20] FAILED                                        [ 50%]
# test_1.py::test_par3[3-21] FAILED                                        [ 75%]
# test_1.py::test_par3[12-4] PASSED                                        [100%]
#
# =================================== FAILURES ===================================
# _______________________________ test_par3[3-20] ________________________________
#
# num1 = 3, num2 = 2
#
#     @pytest.mark.parametrize("num1,num2",[(10,2),(3,2),(3,2),(12,4)])
#     def test_par3(num1,num2):
# >     assert num1 % num2 == 0
# E     assert (3 % 2) == 0
#
# test_1.py:13: AssertionError
# _______________________________ test_par3[3-21] ________________________________
#
# num1 = 3, num2 = 2
#
#     @pytest.mark.parametrize("num1,num2",[(10,2),(3,2),(3,2),(12,4)])
#     def test_par3(num1,num2):
# >     assert num1 % num2 == 0
# E     assert (3 % 2) == 0
#
# test_1.py:13: AssertionError
# --------------- generated xml file: /content/resultadoteste.xml ----------------
# =============== 2 failed, 2 passed, 3 deselected in 0.03 seconds ===============
