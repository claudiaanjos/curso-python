# %% [markdown]
# Prof. Fernando Amaral
#
# www.eia.ai

# %% [markdown]
# # Testes

# %%
# 1.Crie uma função que receba um nome completo e retorne apenas o primeiro nome 
# e o último sobrenome. Por exemplo: Ana da Silva Rosa deve retornar Ana Rosa. 
# Crie uma função de teste parametrizado que teste a função pelo menos 5 vezes.

# %%
from Primeiroultimo import primeiroultimo
print(primeiroultimo("Ana da Silva Rosa"))
# Out:
# Ana Rosa

# %%
# !pytest -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.13, pytest-3.6.4, py-1.11.0, pluggy-0.7.1 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 5 items
#
# test_primeiroultimo.py::test_nomesprimeiroultimo[Fernando Amaral-Fernando Amaral] PASSED [ 20%]
# test_primeiroultimo.py::test_nomesprimeiroultimo[Jos\xe9 Carlos Teixeira-Jos\xe9 Teixeira] PASSED [ 40%]
# test_primeiroultimo.py::test_nomesprimeiroultimo[Ana Maria da Silva Soares-Ana Soares] PASSED [ 60%]
# test_primeiroultimo.py::test_nomesprimeiroultimo[Ana Rosa-Ana Rosa] PASSED [ 80%]
# test_primeiroultimo.py::test_nomesprimeiroultimo[  Maria da Silva Amaral    -Maria Amaral] PASSED [100%]
#
# =========================== 5 passed in 0.03 seconds ===========================

# %%
# 2. Crie uma função que receba um nome completo e retorne a abreviatura, 
# contendo a primeira letra de cada nome em maísculo. Por exemplo: Ana Rosa 
# deve retornar AR. Crie uma função de teste parametrizado que teste a função 
# pelo menos 5 vezes e aborte caso ocorra mais de 2 erros.

# %%
from abreviatura import abreviatura
print(abreviatura("Marcio antonio Silva"))
# Out:
# MAS

# %%
# !pytest -k test_abreviatura -v --maxfail 2
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.13, pytest-3.6.4, py-1.11.0, pluggy-0.7.1 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1
# collected 10 items / 5 deselected
#
# test_abreviatura.py::test_abreviatura[Fernando Amaral-FA] PASSED         [ 20%]
# test_abreviatura.py::test_abreviatura[Jos\xe9 Carlos Teixeira-JCT] PASSED [ 40%]
# test_abreviatura.py::test_abreviatura[Ana Maria da Silva Soares-AMDSS] PASSED [ 60%]
# test_abreviatura.py::test_abreviatura[Ana Rosa-AR] PASSED                [ 80%]
# test_abreviatura.py::test_abreviatura[  Maria da Silva Amaral    -MDSA] PASSED [100%]
#
# ==================== 5 passed, 5 deselected in 0.03 seconds ====================
